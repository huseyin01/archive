# %%
pwd
# Out:
# '/Users/onlyone/github/capstone_project/SIPRI'

# %%
ls
# Out:
# Germany/                         TIV-Import-All-2001-2017.csv
# Iran/                            Untitled.ipynb
# SIPRI-Milex-data-1949-2017.xlsx  Untitled1.ipynb
# TIV-Export-All-2001-2017.csv

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
imp=pd.read_csv('TIV-Import-All-2001-2017.csv', skiprows=9)

# %%
imp.head()
# Out:
#         Unnamed: 0  Unnamed: 1  Unnamed: 2  Unnamed: 3  Unnamed: 4  \
# 0              NaN      2001.0      2002.0      2003.0      2004.0
# 1      Afghanistan         NaN        34.0         NaN         NaN
# 2  African Union**         NaN         NaN         NaN         NaN
# 3          Albania         NaN         NaN         2.0         NaN
# 4          Algeria       542.0       249.0       195.0       242.0
#
#    Unnamed: 5  Unnamed: 6  Unnamed: 7  Unnamed: 8  Unnamed: 9  Unnamed: 10  \
# 0      2005.0      2006.0      2007.0      2008.0      2009.0       2010.0
# 1        35.0         3.0        41.0       150.0       344.0        377.0
# 2        53.0         9.0         NaN        10.0         NaN          NaN
# 3         7.0         NaN         5.0         NaN         NaN          NaN
# 4       159.0       340.0       509.0      1529.0      1075.0        834.0
#
#    Unnamed: 11  Unnamed: 12  Unnamed: 13  Unnamed: 14  Unnamed: 15  \
# ...

# %%
ex=pd.read_csv('TIV-Export-All-2001-2017.csv', skiprows=7)

# %%
ex.head()
# Out:
#   Unnamed: 0  2001  2002  2003  2004  2005  2006  2007  2008  2009   2010  \
# 0    Albania   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN    NaN
# 1    Algeria   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN    NaN
# 2     Angola   NaN   2.0   NaN   NaN   NaN   NaN   NaN   NaN   NaN    NaN
# 3  Argentina   6.0   2.0   NaN   NaN   NaN   2.0   NaN   NaN   NaN    NaN
# 4  Australia  43.0  47.0  44.0   2.0  49.0  14.0  18.0  25.0  80.0  115.0
#
#     2011  2012  2013  2014  2015   2016  2017   Total
# 0    0.0   NaN   NaN   NaN   NaN    NaN   NaN     0.0
# 1    NaN   NaN   NaN   NaN   NaN    0.0   NaN     0.0
# 2    NaN   NaN   NaN   NaN   NaN    NaN   NaN     2.0
# 3    1.0   NaN   NaN   NaN   NaN    NaN   NaN    11.0
# 4  143.0  45.0  54.0  97.0  87.0  134.0  97.0  1092.0

# %%
ex.replace(0, 0.25, inplace=True)

# %%
ex.head()
# Out:
#   Unnamed: 0  2001  2002  2003  2004  2005  2006  2007  2008  2009   2010  \
# 0    Albania   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN    NaN
# 1    Algeria   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN    NaN
# 2     Angola   NaN   2.0   NaN   NaN   NaN   NaN   NaN   NaN   NaN    NaN
# 3  Argentina   6.0   2.0   NaN   NaN   NaN   2.0   NaN   NaN   NaN    NaN
# 4  Australia  43.0  47.0  44.0   2.0  49.0  14.0  18.0  25.0  80.0  115.0
#
#      2011  2012  2013  2014  2015    2016  2017    Total
# 0    0.25   NaN   NaN   NaN   NaN     NaN   NaN     0.25
# 1     NaN   NaN   NaN   NaN   NaN    0.25   NaN     0.25
# 2     NaN   NaN   NaN   NaN   NaN     NaN   NaN     2.00
# 3    1.00   NaN   NaN   NaN   NaN     NaN   NaN    11.00
# 4  143.00  45.0  54.0  97.0  87.0  134.00  97.0  1092.00

# %%
ex.plot()

# %%
from statsmodels.tsa.ar_model import AR
from random import random

# %%
model = AR(ex[:, 1:18])
model_fit = model.fit()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-13-62dbe7c69326> in <module>()
# ----> 1 model = AR(ex[:, 1:18])
#       2 model_fit = model.fit()
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2683             return self._getitem_multilevel(key)
#    2684         else:
# -> 2685             return self._getitem_column(key)
#    2686
#    2687     def _getitem_column(self, key):
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in _getitem_column(self, key)
#    2690         # get column
#    2691         if self.columns.is_unique:
# -> 2692             return self._get_item_cache(key)
#    2693
#    2694         # duplicate columns & possible reduce dimensionality
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/generic.py in _get_item_cache(self, item)
# ...
