# %%
pwd
# Out:
# '/Users/onlyone/Documents/GitHub/Correlates of War Project/War Data'

# %%
ls
# Out:
# Extra-StateWarData_v4.0.csv      Untitled.ipynb
# Inter-StateWarData_v4.0.csv      correlates_of_war_project.ipynb
# Intra-StateWarData_v4.1.csv      intra_state_1
# Non-StateWarData_v4.0.csv

# %%
import pandas as pd

# %%
df=pd.read_csv('intra_state_1')

# %%
df
# Out:
#      Unnamed: 0  WarNum                          WarName  WarType  \
# 0             0     500                   First Caucasus        5
# 1           442     500                   First Caucasus        5
# 2             1     501                   Sidon-Damascus        6
# 3           443     501                   Sidon-Damascus        6
# 4           445     502               First Two Sicilies        4
# 5           444     502               First Two Sicilies        4
# 6             2     502               First Two Sicilies        4
# 7             3     502               First Two Sicilies        4
# 8             4     503                Spanish Royalists        4
# 9           446     503                Spanish Royalists        4
# 10            6     505                 Sardinian Revolt        4
# 11          448     505                 Sardinian Revolt        4
# 12            5     505                 Sardinian Revolt        4
# ...
